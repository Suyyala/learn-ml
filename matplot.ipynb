# %%
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# what is histogram
a = [1, 2, 3, 3, 2 , 5, 7, 5, 3, 3, 4, 9,6, 3,8, 12,  15]
plt.hist(a)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 9, 16, 25]
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.plot(x, y, label="x**2")
plt.show()

# %%
plt.plot(x, y)
plt.title('square')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 4, 9, 16, 25]

fig, ax = plt.subplots(2)  # Creates 2 subplots vertically
ax[0].plot(x, y1, 'r')  # 'r' stands for red color
ax[1].plot(x, y2, 'g')  # 'g' stands for green color
plt.show()

# %%
import numpy as np

x = np.linspace(0, 10, 50)
dy = 0.8  # error
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.show()

plt.clf()  # This will clear the figure

# Now if you plot again, it will be on a new figure
y = np.cos(x)
plt.plot(x, y)
plt.show()

plt.clf()  # This will clear the figure

y = np.tanh(x)
plt.plot(x, y)
plt.show()

plt.clf()  # This will clear the figure

y = np.tan(x)
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of x values
x = np.linspace(0, 10, 100)

# Generate y values for sin and cos waves
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot sin wave
plt.plot(x, y_sin, label='sin', color='blue')

# Plot cos wave
plt.plot(x, y_cos, label='cos', color='red')

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sin and Cos Waves')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
x = np.linspace(0, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

plt.fill_between(x, y1, y2, color='gray', alpha=0.5)

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 40)
X, Y = np.meshgrid(x, y)
Z = np.sqrt(X**2 + Y**2)

plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %%
mu, sigma = 0, 0.1  # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# Create a histogram
count, bins, ignored = plt.hist(s, 30, density=True)

# Plot the distribution curve
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.show()

# %%
mu, sigma = 0, 1  # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# Create a histogram
count, bins, ignored = plt.hist(s, 30, density=True)

# Plot the distribution curve
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.show()

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from skimage import data, exposure

# Load a sample image
img = data.astronaut()
img_arr = np.array(img)

# Plot the histogram
plt.hist(img_arr.ravel(), bins=256, color='gray', alpha=0.7)
plt.title('Histogram before normalization')
plt.show()

# %%
# Normalize the image
img_arr = (img_arr - np.min(img_arr)) / (np.max(img_arr) - np.min(img_arr))

# Plot the histogram of the normalized image
plt.hist(img_arr.ravel(), bins=256, color='gray', alpha=0.7)
plt.title('Histogram after normalization')
plt.show()

# %%
plt.imshow(img_arr)
plt.show()

# %%
from skimage.feature import hog
from skimage import data, exposure
import matplotlib.pyplot as plt

# Load a sample image
image = data.astronaut()

# Compute HOG features
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(1, 1), visualize=True, multichannel=True)

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

# Display original and HOG-processed images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()
# Out:
# <ipython-input-1-ad60971a6784>:9: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(1, 1), visualize=True, multichannel=True)
